# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyt

# %%
df=pd.read_csv("C:\Jupyter\company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df.shape
# Out:
# (12, 9)

# %%
pyt.plot(df["month_number"],df["total_profit"])

# %%
pyt.scatter(df["month_number"],df["toothpaste"])

# %%
pyt.plot(df["month_number"],df["total_profit"],"o:r",linewidth=3,mec="r",mfc="r")
pyt.xlabel="Month Number"
pyt.ylabel="Solid Unit Number"
pyt.legend("total_profit",loc="lower right")
pyt.show()

# %%
df.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
pyt.plot(df["month_number"],df["facecream"])
pyt.plot(df["month_number"],df["facewash"])
pyt.plot(df["month_number"],df["toothpaste"])
pyt.plot(df["month_number"],df["bathingsoap"])
pyt.plot(df["month_number"],df["shampoo"])
pyt.plot(df["month_number"],df["moisturizer"])
pyt.legend({'facecream','facewash','toothpaste','bathingo','shampoo','moisturizer'}, "lower right")
pyt.show()
# Out:
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_328\2288781153.py:7: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   pyt.legend({'facecream','facewash','toothpaste','bathingo','shampoo','moisturizer'}, "lower right")

# %%
pyt.subplot(221)
pyt.bar(df["month_number"],df["facecream"])
pyt.subplot(222)
pyt.bar(df["month_number"],df["facewash"])
# Out:
# <BarContainer object of 12 artists>

# %%
pyt.hist(df["total_profit"])
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <BarContainer object of 10 artists>)

# %%
facecream_sum=sum(df['facecream'])
facewash_sum=sum(df['facewash'])
toothpaste_sum=sum(df['toothpaste'])
bathingsoap_sum=sum(df['bathingsoap'])
shampoo_sum=sum(df['shampoo'])
moisturizer_sum=sum(df['moisturizer'])
sums=[facecream_sum,facewash_sum,toothpaste_sum,bathingsoap_sum,shampoo_sum,moisturizer_sum]
pyt.pie(sums)
pyt.show()
